# %%
cfg = dict(
    seq_length  = 160,
    d_model     = 256,
    latent_dim  = 64,   # latent dimension
    n_head      = 8,
    enc_layers  = 7,
    dec_layers  = 7,
    ff_dim      = 1024,
    dropout     = 0.05,
    emb_dropout = 0.05,

    # special token indices (match your vocabulary)
    pad_idx     = 0,
    sos_idx     = 2,
    eos_idx     = 3,
    # -------- regularization tweaks --------
    label_smoothing = 0.02,   # 0.0 to disable
    corruption_p     = 0.05,  # word-dropout on decoder inputs (train only)

    # -------- validation / decoding --------
    greedy_every  = 1)

# %%
import torch, torch.nn as nn
import model_bs as mdl
import data_utils as du

# --- paths/config you already have ---
vocab_path   = "/home/mmondol/VAE_LLM/LSTM_VAE_Paper/vocab.json"
ckpt_path    = "/home/mmondol/VAE_LLM/LSTM_VAE_Paper/checkpoints/best_model.pth"
test_csv     = "/home/mmondol/VAE_LLM/Data/Test.csv"
dye_csv     = "/home/mmondol/VAE_LLM/Data/dye.csv"

# --- load vocab ---
token_to_idx, idx_to_token = du.load_or_create_vocabulary(csv_paths=[], cache_path=vocab_path, test_smiles=None)
assert token_to_idx["<PAD>"] == cfg["pad_idx"]
assert token_to_idx["<SOS>"] == cfg["sos_idx"]
assert token_to_idx["<EOS>"] == cfg["eos_idx"]

# --- build the same architecture you trained ---
model = mdl.LSTM_VAE_LSTM( vocab_size=len(token_to_idx), d_model=cfg["d_model"], latent_dim=cfg["latent_dim"], pad_idx=cfg["pad_idx"], sos_idx=cfg["sos_idx"], eos_idx=cfg["eos_idx"], enc_layers=cfg["enc_layers"], dec_layers=cfg["dec_layers"], dropout=cfg["dropout"], emb_dropout=cfg["emb_dropout"], max_len=cfg["seq_length"])

# --- load weights robustly (handles 'module.' prefixes if any) ---
state = torch.load(ckpt_path, map_location="cpu")
try:
    model.load_state_dict(state, strict=True)
except RuntimeError:
    # remove a leading 'module.' if the checkpoint came from DataParallel
    from collections import OrderedDict
    new_state = OrderedDict()
    for k, v in state.items():
        new_state[k.replace("module.", "", 1)] = v
    model.load_state_dict(new_state, strict=True)

# --- device & optional DataParallel for speed (not required) ---
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
print("Trainable params:", du.count_parameters(model))
print(f"Encoder parameters: {du.count_parameters(model.encoder)}")
model.eval()

# If you want to keep everything single-GPU-friendly for beam_search, DON'T wrap in DataParallel.
# If you DO wrap, remember to pass model.module to functions that call custom methods.
# Out:
# [vocab] loaded cached vocabulary from /home/mmondol/VAE_LLM/LSTM_VAE_Paper/vocab.json (69 tokens)
# Trainable params: 6773701
# Encoder parameters: 2786048
# /tmp/ipykernel_154078/216399340.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(ckpt_path, map_location="cpu")
# LSTM_VAE_LSTM(
#   (encoder): EncoderBiLSTM(
#     (emb): Embedding(69, 256, padding_idx=0)
#     (emb_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (emb_do): Dropout(p=0.05, inplace=False)
#     (lstm): LSTM(256, 128, num_layers=7, batch_first=True, dropout=0.05, bidirectional=True)
#     (out_do): Dropout(p=0.05, inplace=False)
#     (seq_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (pool_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (to_mu): Linear(in_features=256, out_features=64, bias=True)
#   (to_logvar): Linear(in_features=256, out_features=64, bias=True)
#   (z_to_h0): Linear(in_features=64, out_features=1792, bias=True)
#   (z_to_c0): Linear(in_features=64, out_features=1792, bias=True)
#   (h0_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (c0_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (decoder): DecoderLSTM(
#     (emb): Embedding(69, 256, padding_idx=0)
#     (emb_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (emb_do): Dropout(p=0.05, inplace=False)
#     (lstm): LSTM(256, 256, num_layers=7, batch_first=True, dropout=0.05)
#     (out_ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (out): Linear(in_features=256, out_features=69, bias=True)
#   )
# )

# %%
import pandas as pd
from inference import reconstruct_smiles_table, tensor_to_smiles
import metrics as met

# Use the *unwrapped* model object for beam_search
m = model  # (if you ever wrap with DataParallel, use: model.module)

df_rec = reconstruct_smiles_table(
    smiles_list=None,
    test_csv=test_csv,
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device)

# show a preview
display(df_rec.head(10))

# ------------------------------------------------------------------
# 1.  Token-level accuracy (micro-average over SMILES tokens)
# ------------------------------------------------------------------
def token_accuracy_row(gold, pred):
    g = du.tokenize_smiles(gold)
    p = du.tokenize_smiles(pred)
    L = min(len(g), len(p))
    if L == 0:
        return 0, 0
    correct = sum(gi == pi for gi, pi in zip(g[:L], p[:L]))
    total   = L
    return correct, total

tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy (beam): {exact_match_acc:.4f}")


# ---- summary metrics ----
valid_ratio = (df_rec["valid"] == "yes").mean() if len(df_rec) else float("nan")
avg_lev     = df_rec["lev"].mean() if len(df_rec) else float("nan")

print(f"Greedy validity ratio: {valid_ratio:.3f}")
print(f"Greedy average Levenshtein: {avg_lev:.3f}")
# Out:
#                                                input  \
# 0  CCOC(=O)C1(CC2CC2)CC[NH+]([C@@H](C)CCC2=c3cccc...
# 1  O=C(N[C@@H]1CCN(CC(F)(F)F)C1=O)c1c[nH]c2cccc(F...
# 2  Cc1ccc(C[NH+]2CCC[C@@H]2c2ccc(C(=O)Nc3nc(C)n(C...
# 3  O=C(C[C@@H]1C(=O)N=C2[N-]c3ccccc3N21)Nc1cccc(O...
# 4               CCc1ccc(-c2nc(CSc3nnnn3C3CC3)cs2)cc1
# 5         C[C@H]1CN(C(=O)N[C@@H](C)c2cccc(Br)c2)CCO1
# 6              Cc1ccn(C)c1[C@](O)(C(=O)[O-])C(F)(F)F
# 7  CC(C)N(C[C@@H]1CCCCO1)C(=O)[C@H]1CCc2n[nH]c(C(...
# 8     N[C@H]1C=C[C@H](c2nnc3c(Cl)cc(C(F)(F)F)cn23)C1
# 9  CC[C@@H](C)N(Cc1c(-c2ccccc2F)noc1N1CCOCC1)C(=O...
#
#                                        reconstructed valid  lev
# 0  CCOC(=O)C1(CC2CC2)CC[NH+]([C@@H](C)CCC2=c3cccc...   yes    0
# 1  O=C(N[C@@H]1CCN(CC(F)(F)F)C1=O)c1c[nH]c2cccc(F...   yes    0
# 2  Cc1ccc(C[NH+]2CCC[C@@H]2c2ccc(C(=O)Nc3nc(C)n(C...   yes    0
# 3  O=C(C[C@@H]1C(=O)N=C2[C@H]c3ccccc3N21)Nc1cccc(...   yes    3
# 4               CCc1ccc(-c2nc(CSc3nnnn3C3CC3)cs2)cc1   yes    0
# 5         C[C@H]1CN(C(=O)N[C@@H](C)c2cccc(Br)c2)CCO1   yes    0
# 6              Cc1ccn(C)c1[C@](O)(C(=O)[O-])C(F)(F)F   yes    0
# 7  CC(C)N(C[C@@H]1CCCCO1)C(=O)[C@H]1CCc2nnc(C(F)(...    no    3
# 8     N[C@H]1C=C[C@H](c2nnc3c(Cl)cc(C(F)(F)F)cn23)C1   yes    0
# 9  CC[C@@H](C)N(Cc1c(-c2ccccc2F)noc1N1CCOCC1)C(=O...   yes    0
# Token level test accuracy (beam): 0.9919
# Exact SMILES match accuracy (beam): 0.9630
# Greedy validity ratio: 0.985
# Greedy average Levenshtein: 0.226

# %%
import pandas as pd
from inference import reconstruct_smiles_table
import metrics as met

# Use the *unwrapped* model object for beam_search
m = model  # (if you ever wrap with DataParallel, use: model.module)

df_rec = reconstruct_smiles_table(
    smiles_list=None,
    test_csv=dye_csv,
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device)

# show a preview
display(df_rec.head(40))

# ------------------------------------------------------------------
# 1.  Token-level accuracy (micro-average over SMILES tokens)
# ------------------------------------------------------------------
def token_accuracy_row(gold, pred):
    g = du.tokenize_smiles(gold)
    p = du.tokenize_smiles(pred)
    L = min(len(g), len(p))
    if L == 0:
        return 0, 0
    correct = sum(gi == pi for gi, pi in zip(g[:L], p[:L]))
    total   = L
    return correct, total

tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy (beam): {exact_match_acc:.4f}")


# ---- summary metrics ----
valid_ratio = (df_rec["valid"] == "yes").mean() if len(df_rec) else float("nan")
avg_lev     = df_rec["lev"].mean() if len(df_rec) else float("nan")

print(f"Greedy validity ratio: {valid_ratio:.3f}")
print(f"Greedy average Levenshtein: {avg_lev:.3f}")
# Out:
#                                                 input  \
# 0   O=S1(=O)OC(c2ccc(O)c(Cl)c2)(c2ccc(O)c(Cl)c2)c2...
# 1   O=S1(=O)OC(c2ccc(O)c(Br)c2)(c2ccc(O)c(Br)c2)c2...
# 2   Cc1cc(C2(c3cc(C)c(O)c(Br)c3)OS(=O)(=O)c3ccccc3...
# 3       O=S1(=O)OC(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccccc21
# 4     Cc1cc(O)ccc1C1(c2ccc(O)cc2C)OS(=O)(=O)c2ccccc21
# 5                          CN(C)c1ccc(N=Nc2ccccc2)cc1
# 6           CN(C)c1ccc(N=Nc2ccc(S(=O)(=O)[O-])cc2)cc1
# 7   c1ccc(-c2cc3nc4cccc(-c5ccccc5-c5ccccc5)c4nc3cc...
# 8                    CN(C)c1ccc(N=Nc2ccccc2C(=O)O)cc1
# 9          O=C1OC2(c3ccc(O)cc3Oc3cc(O)ccc32)c2ccccc21
# 10                               CC(=O)C=C(N)c1ccccc1
# 11                             O=C(O)c1cccnc1C(F)(F)F
# 12                       CN(C)c1ccc(C(=O)C(F)(F)F)cc1
# 13                Cc1cc(C=Cc2ccc(N(C)C)cc2)cc(C)[o+]1
# 14                    O=[N+]([O-])c1ccc(Cc2ccncc2)cc1
# 15                 COc1cc(N)c2c(c1N)C(=O)c1ccccc1C2=O
# 16             CCN(CC)c1ccc2nc3c4ccccc4c(=O)cc-3oc2c1
# 17                   CN(C)c1ccc2cc3ccc(N(C)C)cc3nc2c1
# 18  CN(C)c1ccc([C+](c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc...
# 19                                         CC(=O)[O-]
# 20  Cc1cc(C2(c3ccc(O)c(C)c3)OS(=O)(=O)c3ccccc32)ccc1O
# 21         CC1=CC(=O)c2c(Br)cc(Br)c(S(=O)(=O)O)c2C1=O
# 22  Cc1c(Br)cc(Br)c(C(C)c2ccc(C(C)C)c(Br)c2O)c1S(=...
# 23                       Cc1ccccc1N=Nc1ccc(C(N)=O)cc1
# 24    Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1
# 25                      CN(C)c1ccc2c(c1)CN=C2c1ccccc1
# 26                      O=C1c2ccccc2C(=O)c2c(O)cccc21
# 27   O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]
# 28                 CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21
# 29  CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc...
# 30  Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)...
# 31        CN(C)c1ccc2c(c1)CC1=CC(=[N+](C)C)C(=N2)C=C1
# 32            O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21
# 33       O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2O)c1
#
#                                         reconstructed valid  lev
# 0   O=S1(=O)OC(c2ccc(O)c(Cl)c2)(c2ccc(O)c(Cl)c2)c2...   yes    0
# 1   O=S1(=O)OC(c2ccc(O)c(Br)c2)(c2ccc(O)c(Br)c2)c2...   yes    0
# 2   Cc1cc(C2(c3cc(C)c(O)c(Br)c3)S(=O)(=O)c3ccccc32...   yes    1
# 3       O=S1(=O)OC(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccccc21   yes    0
# 4     Cc1cc(O)ccc1C1(c2ccc(O)cc2C)OS(=O)(=O)c2ccccc21   yes    0
# 5                          CN(C)c1ccc(NC(c2ccccc2)cc1    no    2
# 6         CN(C)c1ccc(NC(c2ccc(S(=O)(=O)[O-])cc2)=O)c1    no    5
# 7   c1ccc(-c2cc3nc4cccc(-c5ccccc5-c5ccccc5)c4nc3cc...   yes    0
# 8                    CN(C)c1ccc(NC(c2ccccc2C(=O)O)cc1    no    2
# 9          O=C1OC2(c3ccc(O)cc3Oc3cc(O)ccc32)c2ccccc21   yes    0
# 10                               CC(=O)C=C(N)c1ccccc1   yes    0
# 11                             O=C(O)c1cccnc1C(F)(F)F   yes    0
# 12                       CN(C)c1ccc(C(=O)C(F)(F)F)cc1   yes    0
# 13                   Cc1cc(C=Cc2ccc(N(C)C)cc2)cc(C)c1   yes    4
# 14                       O=S([O-])c1ccc(Cc2ccncc2)cc1   yes    4
# 15                 COc1cc(N)c2c(c1N)C(=O)c1ccccc1C2=O   yes    0
# 16             CCN(CC)c1ccc2nc3c4ccccc4c(=O)ccc3oc2c1    no    1
# 17                   CN(C)c1ccc2cc3ccc(N(C)C)cc3nc2c1   yes    0
# 18   CN(C)c1ccc(C(c2ccc(N(C)C)cc2)=O)cc(N(C)C)cc2)cc1    no    6
# 19                                       CCc1cc(C)cc1    no   10
# 20  Cc1cc(C2(c3ccc(O)c(C)c3)OS(=O)(=O)c3ccccc32)ccc1O   yes    0
# 21         CC1=CC(=O)c2c(Br)cc(Br)c(S(=O)(=O)O)c2C1=O   yes    0
# 22  Cc1c(Br)cc(Br)c(C(C)c2ccc(C(C)C)c(Br)c2O)c1S(=...   yes    0
# 23                       Cc1ccccc1NC(c1ccc(C(N)=O)cc1    no    2
# 24    Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1   yes    0
# 25                      CN(C)c1ccc2c(c1)CN=C2c1ccccc1   yes    0
# 26                      O=C1c2ccccc2C(=O)c2c(O)cccc21   yes    0
# 27   O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]   yes    0
# 28                 CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21   yes    0
# 29  CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc...   yes    0
# 30  Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)...   yes    0
# 31            CN(C)c1ccc2c(c1)CC1=CC(=C(C)C)C(=N)C=C1    no    5
# 32            O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21   yes    0
# 33       O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2O)c1   yes    0
# Token level test accuracy (beam): 0.9639
# Exact SMILES match accuracy (beam): 0.6765
# Greedy validity ratio: 0.765
# Greedy average Levenshtein: 1.235
