# %%
# %load_ext autoreload
# %autoreload 2

import plotting as plt
import torch.nn as nn

from data_utils import load_or_create_vocabulary
from train      import run_training
from inference  import reconstruct_smiles_table
import os
import data_utils as du

# %%
cfg = dict(
    # ---------------- data ----------------
    train_files = [
        "/home/md_halim_mondol/Data/Train_1.csv",
        "/home/md_halim_mondol/Data/Train_2.csv",
        "/home/md_halim_mondol/Data/Train_3.csv"],
    val_files   = ["/home/md_halim_mondol/Data/Valid_1.csv"],
    test_files  = ["/home/md_halim_mondol/Data/Test.csv"],
    seq_length  = 160,
    n_train     = 250000,   # number of training examples
    n_val       = 80000,    # number of validation examples

    # ---------------- model ----------------
    d_model     = 256,
    latent_dim  = 64,   # latent dimension
    enc_layers  = 3,    # CNN depth proxy (still passed through)
    dec_layers  = 7,    # GRU layers
    dropout     = 0.05,
    emb_dropout = 0.05,

    # special token indices (match your vocabulary)
    pad_idx     = 0,
    sos_idx     = 2,
    eos_idx     = 3,

    # -------------- optimization --------------
    batch       = 512,
    lr          = 1e-4,
    weight_decay= 1e-4,
    epochs      = 100,
    early_stop  = 10,
    early_stop_min_delta = 1e-4,
    clip_grad   = 1.0,

    # -------------- schedules --------------
    kl_anneal   = 15,
    kl_max      = 0.02,

    # -------- regularization tweaks --------
    label_smoothing = 0.02,   # 0.0 to disable
    corruption_p     = 0.05,  # word-dropout on decoder inputs (train only)

    # -------- validation / decoding --------
    metrics_every  = 5,   # run beam metrics every N epochs
    beam_size   = 5,

    # ---------------- I/O ----------------
    save_dir    = "./checkpoints",
    save_every  = 10,   # periodic checkpointing

    # -------- (optional) LR scheduler ------
    plateau = dict(mode="min", factor=0.3, patience=3, verbose=True, min_lr=0.0, threshold=1e-4),
)

# %%
all_csvs = cfg["train_files"] + cfg["val_files"] + cfg["test_files"]
token_to_idx, idx_to_token = load_or_create_vocabulary(all_csvs, cache_path="vocab.json", test_smiles=None)

assert token_to_idx["<PAD>"] == cfg["pad_idx"], "PAD index mismatch with cached vocab"
assert token_to_idx["<SOS>"] == cfg["sos_idx"], "SOS index mismatch with cached vocab"
assert token_to_idx["<EOS>"] == cfg["eos_idx"], "EOS index mismatch with cached vocab"
print("Vocab size:", len(token_to_idx))
print(token_to_idx)
print("Special tokens:")
print("PAD:", token_to_idx["<PAD>"])
print("SOS:", token_to_idx["<SOS>"])
print("EOS:", token_to_idx["<EOS>"])
# Out:
# [vocab] loaded cached vocabulary from vocab.json (49 tokens)
# Vocab size: 49
# {'<PAD>': 0, '<UNK>': 1, '<SOS>': 2, '<EOS>': 3, 'O': 4, '=': 5, 'C': 6, '1': 7, 'N': 8, '[C@@H]': 9, '[NH+]': 10, '(': 11, 'c': 12, '2': 13, ')': 14, '(=O)': 15, 'S': 16, '3': 17, 'n': 18, '-': 19, '[C@H]': 20, '4': 21, 's': 22, '[': 23, ']': 24, 'F': 25, '#': 26, 'H': 27, '[nH+]': 28, 'Cl': 29, 'o': 30, '[NH2+]': 31, '@': 32, '+': 33, 'Br': 34, '[O-]': 35, '[N-]': 36, '/': 37, '\\': 38, '5': 39, 'I': 40, '6': 41, '[N+]': 42, '7': 43, 'p': 44, '.': 45, 'P': 46, '8': 47, '9': 48}
# Special tokens:
# PAD: 0
# SOS: 2
# EOS: 3

# %%
model, history = run_training(cfg, token_to_idx, idx_to_token)
# Out:
# Using device: cuda
# Visible CUDA devices: 2
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:160: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler  = torch.cuda.amp.GradScaler(enabled=use_amp)
# /home/md_halim_mondol/anaconda3/envs/cheminf/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Epoch  1: train 2.4801/0.299  val(tf) 2.2757/0.358  KL 0.00
# Epoch  2: train 2.2679/0.347  val(tf) 2.1800/0.371  KL 0.00
# Epoch  3: train 2.1663/0.379  val(tf) 2.0283/0.420  KL 0.00
# Epoch  4: train 1.9934/0.434  val(tf) 1.7427/0.487  KL 0.01
# Epoch  5: train 1.6802/0.520  val(tf) 1.4548/0.576  beam_acc 0.325  valid 0.045  lev 25.97  KL 0.01
# Epoch  6: train 1.4811/0.587  val(tf) 1.2964/0.614  KL 0.01
# Epoch  7: train 1.3453/0.634  val(tf) 1.1754/0.652  KL 0.01
# Epoch  8: train 1.2437/0.665  val(tf) 1.0811/0.682  KL 0.01
# Epoch  9: train 1.1678/0.688  val(tf) 0.9993/0.702  KL 0.01
# Epoch 10: train 1.1051/0.707  val(tf) 0.9373/0.722  beam_acc 0.316  valid 0.199  lev 23.30  KL 0.01
# Epoch 11: train 1.0519/0.723  val(tf) 0.8785/0.738  KL 0.01
# Epoch 12: train 1.0040/0.738  val(tf) 0.8343/0.749  KL 0.02
# Epoch 13: train 0.9637/0.751  val(tf) 0.7849/0.765  KL 0.02
# Epoch 14: train 0.9281/0.763  val(tf) 0.7437/0.778  KL 0.02
# Epoch 15: train 0.8924/0.774  val(tf) 0.7062/0.791  beam_acc 0.356  valid 0.269  lev 21.19  KL 0.02
# Epoch 16: train 0.8548/0.786  val(tf) 0.6490/0.807  KL 0.02
# Epoch 17: train 0.8205/0.798  val(tf) 0.6176/0.818  KL 0.02
# Epoch 18: train 0.7896/0.808  val(tf) 0.5770/0.831  KL 0.02
# Epoch 19: train 0.7625/0.817  val(tf) 0.5517/0.839  KL 0.02
# Epoch 20: train 0.7362/0.825  val(tf) 0.5239/0.850  beam_acc 0.451  valid 0.408  lev 17.77  KL 0.02
# Epoch 21: train 0.7127/0.833  val(tf) 0.4969/0.857  KL 0.02
# Epoch 22: train 0.6897/0.841  val(tf) 0.4684/0.867  KL 0.02
# Epoch 23: train 0.6684/0.848  val(tf) 0.4430/0.875  KL 0.02
# Epoch 24: train 0.6484/0.855  val(tf) 0.4180/0.882  KL 0.02
# Epoch 25: train 0.6317/0.861  val(tf) 0.4062/0.884  beam_acc 0.549  valid 0.551  lev 14.34  KL 0.02
# Epoch 26: train 0.6147/0.867  val(tf) 0.3829/0.893  KL 0.02
# Epoch 27: train 0.5991/0.873  val(tf) 0.3657/0.901  KL 0.02
# Epoch 28: train 0.5843/0.878  val(tf) 0.3511/0.906  KL 0.02
# Epoch 29: train 0.5706/0.883  val(tf) 0.3343/0.911  KL 0.02
# Epoch 30: train 0.5573/0.888  val(tf) 0.3231/0.915  beam_acc 0.647  valid 0.639  lev 11.21  KL 0.02
# Epoch 31: train 0.5450/0.892  val(tf) 0.3119/0.919  KL 0.02
# Epoch 32: train 0.5332/0.897  val(tf) 0.3038/0.922  KL 0.02
# Epoch 33: train 0.5224/0.901  val(tf) 0.2893/0.927  KL 0.02
# Epoch 34: train 0.5111/0.906  val(tf) 0.2771/0.932  KL 0.02
# Epoch 35: train 0.5005/0.910  val(tf) 0.2624/0.937  beam_acc 0.718  valid 0.718  lev 8.79  KL 0.02
# Epoch 36: train 0.4903/0.914  val(tf) 0.2558/0.938  KL 0.02
# Epoch 37: train 0.4808/0.917  val(tf) 0.2448/0.945  KL 0.02
# Epoch 38: train 0.4715/0.921  val(tf) 0.2336/0.948  KL 0.02
# Epoch 39: train 0.4637/0.924  val(tf) 0.2283/0.949  KL 0.02
# Epoch 40: train 0.4558/0.927  val(tf) 0.2213/0.952  beam_acc 0.782  valid 0.789  lev 6.67  KL 0.02
# Epoch 41: train 0.4481/0.929  val(tf) 0.2115/0.955  KL 0.02
# Epoch 42: train 0.4405/0.932  val(tf) 0.2128/0.954  KL 0.02
# Epoch 43: train 0.4335/0.935  val(tf) 0.2019/0.958  KL 0.02
# Epoch 44: train 0.4270/0.937  val(tf) 0.1941/0.961  KL 0.02
# Epoch 45: train 0.4207/0.939  val(tf) 0.1878/0.963  beam_acc 0.829  valid 0.837  lev 5.16  KL 0.02
# Epoch 46: train 0.4146/0.941  val(tf) 0.1846/0.964  KL 0.02
# Epoch 47: train 0.4091/0.943  val(tf) 0.1781/0.967  KL 0.02
# Epoch 48: train 0.4037/0.945  val(tf) 0.1730/0.968  KL 0.02
# Epoch 49: train 0.3987/0.947  val(tf) 0.1679/0.969  KL 0.02
# Epoch 50: train 0.3933/0.949  val(tf) 0.1640/0.971  beam_acc 0.866  valid 0.868  lev 4.06  KL 0.02
# Epoch 51: train 0.3892/0.950  val(tf) 0.1620/0.972  KL 0.02
# Epoch 52: train 0.3848/0.951  val(tf) 0.1570/0.973  KL 0.02
# Epoch 53: train 0.3805/0.953  val(tf) 0.1539/0.974  KL 0.02
# Epoch 54: train 0.3763/0.954  val(tf) 0.1502/0.974  KL 0.02
# Epoch 55: train 0.3722/0.956  val(tf) 0.1475/0.976  beam_acc 0.891  valid 0.891  lev 3.25  KL 0.02
# Epoch 56: train 0.3687/0.957  val(tf) 0.1474/0.976  KL 0.02
# Epoch 57: train 0.3653/0.958  val(tf) 0.1425/0.977  KL 0.02
# Epoch 58: train 0.3613/0.959  val(tf) 0.1395/0.978  KL 0.02
# Epoch 59: train 0.3580/0.960  val(tf) 0.1367/0.979  KL 0.02
# Epoch 60: train 0.3549/0.961  val(tf) 0.1359/0.980  beam_acc 0.904  valid 0.904  lev 2.80  KL 0.02
# Epoch 61: train 0.3516/0.962  val(tf) 0.1314/0.981  KL 0.02
# Epoch 62: train 0.3486/0.963  val(tf) 0.1293/0.981  KL 0.02
# Epoch 63: train 0.3456/0.964  val(tf) 0.1278/0.981  KL 0.02
# Epoch 64: train 0.3428/0.965  val(tf) 0.1249/0.982  KL 0.02
# Epoch 65: train 0.3399/0.966  val(tf) 0.1239/0.983  beam_acc 0.921  valid 0.925  lev 2.27  KL 0.02
# Epoch 66: train 0.3371/0.967  val(tf) 0.1219/0.983  KL 0.02
# Epoch 67: train 0.3347/0.968  val(tf) 0.1184/0.984  KL 0.02
# Epoch 68: train 0.3319/0.968  val(tf) 0.1188/0.984  KL 0.02
# Epoch 69: train 0.3298/0.969  val(tf) 0.1163/0.985  KL 0.02
# Epoch 70: train 0.3274/0.970  val(tf) 0.1151/0.985  beam_acc 0.927  valid 0.932  lev 2.04  KL 0.02
# Epoch 71: train 0.3256/0.970  val(tf) 0.1142/0.985  KL 0.02
# Epoch 72: train 0.3230/0.971  val(tf) 0.1125/0.986  KL 0.02
# Epoch 73: train 0.3210/0.972  val(tf) 0.1100/0.986  KL 0.02
# Epoch 74: train 0.3189/0.972  val(tf) 0.1119/0.985  KL 0.02
# Epoch 75: train 0.3168/0.973  val(tf) 0.1096/0.986  beam_acc 0.939  valid 0.943  lev 1.77  KL 0.02
# Epoch 76: train 0.3152/0.973  val(tf) 0.1081/0.987  KL 0.02
# Epoch 77: train 0.3132/0.974  val(tf) 0.1049/0.988  KL 0.02
# Epoch 78: train 0.3116/0.974  val(tf) 0.1025/0.988  KL 0.02
# Epoch 79: train 0.3097/0.975  val(tf) 0.1046/0.987  KL 0.02
# Epoch 80: train 0.3079/0.975  val(tf) 0.1037/0.988  beam_acc 0.943  valid 0.950  lev 1.58  KL 0.02
# Epoch 81: train 0.3065/0.976  val(tf) 0.1030/0.988  KL 0.02
# Epoch 82: train 0.3045/0.976  val(tf) 0.0991/0.989  KL 0.02
# Epoch 83: train 0.3033/0.977  val(tf) 0.1002/0.989  KL 0.02
# Epoch 84: train 0.3019/0.977  val(tf) 0.0982/0.989  KL 0.02
# Epoch 85: train 0.3002/0.978  val(tf) 0.0981/0.989  beam_acc 0.947  valid 0.955  lev 1.46  KL 0.02
# Epoch 86: train 0.2987/0.978  val(tf) 0.0952/0.990  KL 0.02
# Epoch 87: train 0.2977/0.978  val(tf) 0.0948/0.990  KL 0.02
# Epoch 88: train 0.2961/0.979  val(tf) 0.0958/0.989  KL 0.02
# Epoch 89: train 0.2948/0.979  val(tf) 0.0947/0.990  KL 0.02
# Epoch 90: train 0.2935/0.979  val(tf) 0.0932/0.990  beam_acc 0.953  valid 0.960  lev 1.31  KL 0.02
# Epoch 91: train 0.2924/0.980  val(tf) 0.0903/0.991  KL 0.02
# Epoch 92: train 0.2910/0.980  val(tf) 0.0932/0.990  KL 0.02
# Epoch 93: train 0.2896/0.980  val(tf) 0.0917/0.991  KL 0.02
# Epoch 94: train 0.2887/0.981  val(tf) 0.0890/0.992  KL 0.02
# Epoch 95: train 0.2876/0.981  val(tf) 0.0895/0.991  beam_acc 0.957  valid 0.964  lev 1.17  KL 0.02
# Epoch 96: train 0.2863/0.981  val(tf) 0.0881/0.992  KL 0.02
# Epoch 97: train 0.2853/0.981  val(tf) 0.0874/0.992  KL 0.02
# Epoch 98: train 0.2842/0.982  val(tf) 0.0858/0.992  KL 0.02
# Epoch 99: train 0.2831/0.982  val(tf) 0.0858/0.992  KL 0.02
# Epoch 100: train 0.2821/0.982  val(tf) 0.0870/0.992  beam_acc 0.956  valid 0.959  lev 1.19  KL 0.02
# Total training time: 132.02 min

# %%
plt.plot_training_curves(history, metrics_every=cfg["metrics_every"], save_path=os.path.join(cfg["save_dir"], "training_curves.png"))
# Out:
# [plot] saved to ./checkpoints/training_curves.png
# (<Figure size 1500x800 with 6 Axes>,
#  array([[<Axes: title={'center': 'Loss'}, ylabel='CE+KL'>,
#          <Axes: title={'center': 'Token level Acc'}>,
#          <Axes: title={'center': 'Validation accuracy with beam search'}>],
#         [<Axes: title={'center': 'Validity Ratio'}, xlabel='epoch'>,
#          <Axes: title={'center': 'Average Levenshtein Distance'}, xlabel='epoch'>,
#          <Axes: xlabel='epoch'>]], dtype=object))

# %%
# # ─── Cell 5 : SMILES reconstruction demo ─────────────────────────────────────

Dye_smiles = [
'CC1=CC(=O)c2c(Br)cc(Br)c(S(=O)(=O)O)c2C1=O',
'Cc1c(Br)cc(Br)c(C(C)c2ccc(C(C)C)c(Br)c2O)c1S(=O)(=O)O',
'Cc1ccccc1N=Nc1ccc(C(N)=O)cc1',
'Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1',
'CN(C)c1ccc2c(c1)CN=C2c1ccccc1',
'O=C1c2ccccc2C(=O)c2c(O)cccc21',
'O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]',
'CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21',
'CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc2)cc1',
'Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)cc2)cc1',
'CN(C)c1ccc2c(c1)CC1=CC(=[N+](C)C)C(=N2)C=C1',
'O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21',
'O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2O)c1']


# Dye_names = [
#     'Bromophenol Blue',
#     'Bromothymol Blue',
#     'Acetic acid',
#     'Phenol Red',
#     'Neutral Red',
#     'Alizarin Red S',
#     'Indigo Carmine',
#     'Methylene Blue',
#     'Crystal Violet',
#     'Thymolphthalein',
#     'Safranin O',
#     'Eosin Y',
#     'Fluorescein']

# %%
m = model.module if isinstance(model, nn.DataParallel) else model
device = next(m.parameters()).device

df_rec = reconstruct_smiles_table(
    smiles_list=None,
    test_csv=cfg["test_files"][0],
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device,
    mode="beam",
    beam_size=cfg["beam_size"])

df_rec.tail(20)
# Out:
#                                                  input  \
# 249        COC(=O)Cn1c(CCNC(=O)c2ccccc2)[nH+]c2ccccc21
# 250       CC(C)=CC(=O)NCc1cc[nH+]c(N2CCO[C@@H](C)C2)c1
# 251              [NH3+]CC1([C@H](O)c2ccccc2OC(F)F)CCC1
# 252  COC(=O)c1nn(CC(=O)NCCc2ccc(OC)c(OC)c2)c(=O)c2n...
# 253  Cc1cnc(NC(=O)N[C@@H](C)c2ccc(S(=O)(=O)N(C)C)cc...
# 254  CCOC(=O)c1cnn([C@H]2CCCN(C(=O)Nc3cccc(N(C)CC)c...
# 255  CCCCNC(=O)[C@H]1[C@H]2C=C[C@]3(CN(c4cc(C)on4)C...
# 256  CC(C)[C@@H]1CN(Cc2c[nH]nc2-c2ccc(Cl)cc2)C[C@H]...
# 257                 CC(C)N(Cc1ccc(Cl)nc1)C[C@H]1CCCCO1
# 258           c1ccc(-c2nc(CN3CCC[C@H]3c3ccccc3)no2)cc1
# 259                 CC(C)C[C@@H](CN)C(=O)NCCCC(=O)[O-]
# 260    O[C@H](C[C@H]1CCCN1c1ccc(OC(F)F)cn1)c1ccc(F)cc1
# 261  CCn1nc(C(=O)[O-])c2c1CC[C@@H]([NH2+]CCCN1CCOCC...
# 262           Cc1nn(CCO)c(C)c1C[NH+]1CCC[C@@](C)(CO)C1
# 263  O=C1C[C@@H](CNC(=O)Nc2cccc(-c3ncon3)c2)c2ccccc2N1
# 264       O=S(=O)([O-])C1=CC2=NC(c3ccccc3)=N[C@H]2C=C1
# 265                CN(Cc1nccs1)C(=O)[C@@H]1CSc2ccccc21
# 266    CCCN(CC(F)F)C(=O)N[C@H](C)c1nc(-c2cccc(F)c2)no1
# 267            Cc1cc(NC(=O)c2ccc3[nH]c[nH+]c3c2)ncc1Br
# 268  Cc1ccc(O[C@H](C)C(=O)Nc2ccc(S(=O)(=O)[N-]c3cc(...
#
#                                          reconstructed valid  lev
# 249        COC(=O)Cn1c(CCNC(=O)c2ccccc2)[nH+]c2ccccc21   yes    0
# 250       CC(C)=CC(=O)NCc1cc[nH+]c(N2CCO[C@@H](C)C2)c1   yes    0
# 251              [NH3+]CC1([C@H](O)c2ccccc2OC(F)F)CCC1   yes    0
# 252  COC(=O)c1nn(CC(=O)NCCc2ccc(OC)c(OC)c2)c(=O)c2n...   yes    2
# 253  Cc1cnc(NC(=O)N[C@@H](C)c2ccc(S(=O)(=O)N(C)C)cc...   yes    0
# 254  CCOC(=O)c1cnn([C@H]2CCCN(C(=O)Nc3cccc(N(C)C)c3...   yes    2
# 255  CCCCNC(=O)[C@H]1[C@H]2C=C[C@]3(CN(c4cc(C)on4)C...   yes    2
# 256  CC(C)[C@@H]1CN(Cc2c[nH]nc2-c2ccc(Cl)cc2)C[C@H]...   yes    0
# 257                 CC(C)N(Cc1ccc(Cl)nc1)C[C@H]1CCCCO1   yes    0
# 258           c1ccc(-c2nc(CN3CCC[C@H]3c3ccccc3)no2)cc1   yes    0
# 259                 CC(C)C[C@@H](CN)C(=O)NCCCC(=O)[O-]   yes    0
# 260    O[C@H](C[C@H]1CCCN1c1ccc(OC(F)F)cn1)c1ccc(F)cc1   yes    0
# 261  CCn1nc(C(=O)[O-])c2c1CC[C@@H]([NH2+]CCCN1CCOCC...   yes    0
# 262           Cc1nn(CCO)c(C)c1C[NH+]1CCC[C@@](C)(CO)C1   yes    0
# 263  O=C1C[C@@H](CNC(=O)Nc2cccc(-c3ncoc3)n2)c2ccccc...   yes    4
# 264      O=S(=O)([O-])C1=C2CC=NC(c3ccccc3)=N[C@H]2C=C1   yes    2
# 265                CN(Cc1nccs1)C(=O)[C@@H]1CSc2ccccc21   yes    0
# 266    CCCN(CC(F)F)C(=O)N[C@H](C)c1nc(-c2cccc(F)c2)no1   yes    0
# 267            Cc1cc(NC(=O)c2ccc3[nH]c[nH+]c3c2)ncc1Br   yes    0
# 268  Cc1ccc(O[C@H](C)C(=O)Nc2ccc(S(=O)(=O)[N-]c3cc(...   yes    0

# %%
# ------------------------------------------------------------------
# 1.  Token-level accuracy (micro-average over SMILES tokens)
# ------------------------------------------------------------------
def token_accuracy_row(gold, pred):
    g = du.tokenize_smiles(gold)
    p = du.tokenize_smiles(pred)
    L = min(len(g), len(p))
    if L == 0:                      # degenerate empty case
        return 0, 0
    correct = sum(gi == pi for gi, pi in zip(g[:L], p[:L]))
    total   = L
    return correct, total

tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy (beam): {exact_match_acc:.4f}")
# Out:
# Token level test accuracy (beam): 0.9581
# Exact SMILES match accuracy (beam): 0.8736

# %%
df_rec = reconstruct_smiles_table(
    smiles_list=Dye_smiles,
    test_csv=None,
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device,
    mode="beam",
    beam_size=cfg["beam_size"])

df_rec.head(20)
# Out:
#                                                 input  \
# 0          CC1=CC(=O)c2c(Br)cc(Br)c(S(=O)(=O)O)c2C1=O
# 1   Cc1c(Br)cc(Br)c(C(C)c2ccc(C(C)C)c(Br)c2O)c1S(=...
# 2                        Cc1ccccc1N=Nc1ccc(C(N)=O)cc1
# 3     Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1
# 4                       CN(C)c1ccc2c(c1)CN=C2c1ccccc1
# 5                       O=C1c2ccccc2C(=O)c2c(O)cccc21
# 6    O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]
# 7                  CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21
# 8   CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc...
# 9   Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)...
# 10        CN(C)c1ccc2c(c1)CC1=CC(=[N+](C)C)C(=N2)C=C1
# 11            O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21
# 12       O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2O)c1
#
#                                         reconstructed valid  lev
# 0     CC1=CC[C@@H](c2cc(Br)cs2)[C@H](S(=O)(=O)OC)c2s1    no   20
# 1   Cc1c(Br)cc(Br)c(C(Cc2ccc(C)c(C)o2)=O)c1[C@H](N...    no   24
# 2                      Cc1ccccc1N1Cc2ccc(SC(N)=O)cc21   yes    5
# 3     Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1   yes    0
# 4                       CN(C)c1ccc2c(c1)CN=C2c1ccccc1   yes    0
# 5                       O=C1c2ccccc2C(=O)c2c(O)cccc21   yes    0
# 6    O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]   yes    0
# 7                  CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21   yes    0
# 8   CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc...   yes    0
# 9   Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)...   yes    0
# 10        CN(C)c1ccc2c(c1)CC1=C(C1=C(C)C([O-])=O)C=C2   yes   15
# 11            O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21   yes    0
# 12       O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2)c1O   yes    2

# %%
tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy for Dye SMILES (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy for Dye SMILES (beam): {exact_match_acc:.4f}")
# Out:
# Token level test accuracy for Dye SMILES (beam): 0.8309
# Exact SMILES match accuracy for Dye SMILES (beam): 0.6154
