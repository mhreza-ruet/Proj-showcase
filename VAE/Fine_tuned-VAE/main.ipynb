# %%
# %load_ext autoreload
# %autoreload 2

import plotting as plt
import torch.nn as nn
from train      import run_training
from inference  import reconstruct_smiles_table
import os
import data_utils as du

# %%
cfg = dict(
    # ---------------- data ----------------
    train_files = [
        "/home/md_halim_mondol/Data/Train_1.csv",
        "/home/md_halim_mondol/Data/Train_2.csv",
        "/home/md_halim_mondol/Data/Train_3.csv"],
    val_files   = ["/home/md_halim_mondol/Data/Valid_1.csv"],
    test_files  = ["/home/md_halim_mondol/Data/Test.csv"],
    seq_length  = 160,
    n_train     = 250000,   # number of training examples
    n_val       = 80000,    # number of validation examples

    # ---------------- model ----------------
    d_model     = 256,
    latent_dim  = 64,   # latent dimension
    enc_layers  = 3,    # CNN depth proxy (still passed through)
    dec_layers  = 7,    # GRU layers
    dropout     = 0.05,
    emb_dropout = 0.05,

    # special token indices (match your vocabulary)
    pad_idx     = 0,
    sos_idx     = 2,
    eos_idx     = 3,

    # -------------- optimization --------------
    batch       = 512,
    lr          = 1e-4,
    weight_decay= 1e-4,
    epochs      = 100,
    early_stop  = 10,
    early_stop_min_delta = 1e-4,
    clip_grad   = 1.0,

    # -------------- schedules --------------
    kl_anneal   = 15,
    kl_max      = 0.02,

    # -------- regularization tweaks --------
    label_smoothing = 0.02,   # 0.0 to disable
    corruption_p     = 0.05,  # word-dropout on decoder inputs (train only)

    # -------- validation / decoding --------
    metrics_every  = 5,   # run beam metrics every N epochs
    beam_size   = 5,

    # ---------------- I/O ----------------
    save_dir    = "./checkpoints",
    save_every  = 10,   # periodic checkpointing

    # -------- (optional) LR scheduler ------
    plateau = dict(mode="min", factor=0.3, patience=3, verbose=True, min_lr=0.0, threshold=1e-4),
)

# %%
all_csvs = cfg["train_files"] + cfg["val_files"] + cfg["test_files"] + ["/home/md_halim_mondol/Data/VOC_Dye.csv"]
token_to_idx, idx_to_token = du.load_or_create_vocabulary(all_csvs, cache_path="vocab.json", test_smiles=None)

assert token_to_idx["<PAD>"] == cfg["pad_idx"], "PAD index mismatch with cached vocab"
assert token_to_idx["<SOS>"] == cfg["sos_idx"], "SOS index mismatch with cached vocab"
assert token_to_idx["<EOS>"] == cfg["eos_idx"], "EOS index mismatch with cached vocab"
print("Vocab size:", len(token_to_idx))
print(token_to_idx)
print("Special tokens:")
print("PAD:", token_to_idx["<PAD>"])
print("SOS:", token_to_idx["<SOS>"])
print("EOS:", token_to_idx["<EOS>"])
# Out:
# [vocab] loaded cached vocabulary from vocab.json (69 tokens)
# Vocab size: 69
# {'<PAD>': 0, '<UNK>': 1, '<SOS>': 2, '<EOS>': 3, 'O': 4, '=': 5, 'C': 6, '1': 7, 'N': 8, '[C@@H]': 9, '[NH+]': 10, '(': 11, 'c': 12, '2': 13, '(O)': 14, ')': 15, '(=O)': 16, 'S': 17, '3': 18, 'n': 19, '-': 20, '[C@H]': 21, '4': 22, 's': 23, '(C)': 24, '[': 25, ']': 26, '(F)': 27, 'F': 28, '#': 29, '[nH]': 30, '[nH+]': 31, '(Cl)': 32, 'o': 33, '[NH2+]': 34, '@': 35, 'H': 36, '+': 37, '(Br)': 38, '[O-]': 39, 'Cl': 40, '[N-]': 41, '/': 42, '\\': 43, 'Br': 44, '5': 45, '(I)': 46, 'I': 47, '6': 48, '[N+]': 49, '[n+]': 50, '[o+]': 51, '7': 52, 'p': 53, '.': 54, 'P': 55, '8': 56, '9': 57, 'A': 58, 'B': 59, '[Na+]': 60, '[Zn]': 61, '[Co+2]': 62, '[Cd+2]': 63, '[Cl-]': 64, '[Cr+3]': 65, '[B-]': 66, '[C+]': 67, '[Pb+2]': 68}
# Special tokens:
# PAD: 0
# SOS: 2
# EOS: 3

# %%
model, history = run_training(cfg, token_to_idx, idx_to_token)
# Out:
# Using device: cuda
# Visible CUDA devices: 2
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:160: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler  = torch.cuda.amp.GradScaler(enabled=use_amp)
# /home/md_halim_mondol/anaconda3/envs/cheminf/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /home/md_halim_mondol/LSTM_VAE_Paper/train.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Epoch  1: train 2.5825/0.306  val(tf) 2.3301/0.339  KL 0.00
# Epoch  2: train 2.3368/0.361  val(tf) 2.1947/0.391  KL 0.00
# Epoch  3: train 2.2361/0.388  val(tf) 2.0991/0.419  KL 0.00
# Epoch  4: train 2.1337/0.418  val(tf) 1.9447/0.454  KL 0.01
# Epoch  5: train 1.9757/0.462  val(tf) 1.6752/0.526  beam_acc 0.393  valid 0.049  lev 25.94  KL 0.01
# Epoch  6: train 1.6643/0.548  val(tf) 1.4360/0.594  KL 0.01
# Epoch  7: train 1.4858/0.607  val(tf) 1.2746/0.633  KL 0.01
# Epoch  8: train 1.3574/0.647  val(tf) 1.1701/0.662  KL 0.01
# Epoch  9: train 1.2515/0.676  val(tf) 1.0625/0.692  KL 0.01
# Epoch 10: train 1.1738/0.696  val(tf) 0.9798/0.712  beam_acc 0.396  valid 0.209  lev 21.89  KL 0.01
# Epoch 11: train 1.1062/0.714  val(tf) 0.9089/0.731  KL 0.01
# Epoch 12: train 1.0531/0.729  val(tf) 0.8494/0.747  KL 0.02
# Epoch 13: train 1.0042/0.744  val(tf) 0.7925/0.765  KL 0.02
# Epoch 14: train 0.9609/0.758  val(tf) 0.7431/0.781  KL 0.02
# Epoch 15: train 0.9221/0.770  val(tf) 0.7104/0.790  beam_acc 0.432  valid 0.346  lev 18.96  KL 0.02
# Epoch 16: train 0.8861/0.781  val(tf) 0.6659/0.804  KL 0.02
# Epoch 17: train 0.8532/0.792  val(tf) 0.6260/0.814  KL 0.02
# Epoch 18: train 0.8236/0.801  val(tf) 0.5974/0.824  KL 0.02
# Epoch 19: train 0.7963/0.810  val(tf) 0.5694/0.835  KL 0.02
# Epoch 20: train 0.7715/0.818  val(tf) 0.5347/0.843  beam_acc 0.501  valid 0.485  lev 16.32  KL 0.02
# Epoch 21: train 0.7458/0.826  val(tf) 0.5086/0.854  KL 0.02
# Epoch 22: train 0.7224/0.834  val(tf) 0.4840/0.861  KL 0.02
# Epoch 23: train 0.6990/0.842  val(tf) 0.4594/0.868  KL 0.02
# Epoch 24: train 0.6773/0.849  val(tf) 0.4398/0.874  KL 0.02
# Epoch 25: train 0.6577/0.856  val(tf) 0.4112/0.885  beam_acc 0.596  valid 0.592  lev 12.96  KL 0.02
# Epoch 26: train 0.6385/0.863  val(tf) 0.3896/0.893  KL 0.02
# Epoch 27: train 0.6214/0.869  val(tf) 0.3738/0.898  KL 0.02
# Epoch 28: train 0.6050/0.875  val(tf) 0.3596/0.903  KL 0.02
# Epoch 29: train 0.5898/0.880  val(tf) 0.3489/0.908  KL 0.02
# Epoch 30: train 0.5758/0.885  val(tf) 0.3264/0.914  beam_acc 0.682  valid 0.700  lev 9.96  KL 0.02
# Epoch 31: train 0.5625/0.890  val(tf) 0.3125/0.919  KL 0.02
# Epoch 32: train 0.5490/0.895  val(tf) 0.3031/0.923  KL 0.02
# Epoch 33: train 0.5368/0.900  val(tf) 0.2883/0.929  KL 0.02
# Epoch 34: train 0.5249/0.905  val(tf) 0.2763/0.934  KL 0.02
# Epoch 35: train 0.5134/0.909  val(tf) 0.2640/0.939  beam_acc 0.755  valid 0.771  lev 7.61  KL 0.02
# Epoch 36: train 0.5036/0.913  val(tf) 0.2507/0.943  KL 0.02
# Epoch 37: train 0.4938/0.916  val(tf) 0.2494/0.943  KL 0.02
# Epoch 38: train 0.4847/0.920  val(tf) 0.2352/0.948  KL 0.02
# Epoch 39: train 0.4757/0.923  val(tf) 0.2277/0.950  KL 0.02
# Epoch 40: train 0.4675/0.926  val(tf) 0.2197/0.953  beam_acc 0.808  valid 0.825  lev 5.88  KL 0.02
# Epoch 41: train 0.4591/0.929  val(tf) 0.2119/0.956  KL 0.02
# Epoch 42: train 0.4516/0.931  val(tf) 0.2022/0.959  KL 0.02
# Epoch 43: train 0.4446/0.934  val(tf) 0.1982/0.959  KL 0.02
# Epoch 44: train 0.4373/0.936  val(tf) 0.1918/0.962  KL 0.02
# Epoch 45: train 0.4309/0.939  val(tf) 0.1841/0.964  beam_acc 0.854  valid 0.854  lev 4.39  KL 0.02
# Epoch 46: train 0.4249/0.941  val(tf) 0.1826/0.964  KL 0.02
# Epoch 47: train 0.4186/0.943  val(tf) 0.1745/0.967  KL 0.02
# Epoch 48: train 0.4133/0.945  val(tf) 0.1705/0.968  KL 0.02
# Epoch 49: train 0.4082/0.947  val(tf) 0.1641/0.971  KL 0.02
# Epoch 50: train 0.4026/0.949  val(tf) 0.1601/0.972  beam_acc 0.881  valid 0.875  lev 3.53  KL 0.02
# Epoch 51: train 0.3980/0.950  val(tf) 0.1561/0.973  KL 0.02
# Epoch 52: train 0.3935/0.952  val(tf) 0.1542/0.974  KL 0.02
# Epoch 53: train 0.3892/0.953  val(tf) 0.1496/0.976  KL 0.02
# Epoch 54: train 0.3850/0.954  val(tf) 0.1465/0.976  KL 0.02
# Epoch 55: train 0.3811/0.956  val(tf) 0.1446/0.977  beam_acc 0.892  valid 0.889  lev 3.13  KL 0.02
# Epoch 56: train 0.3774/0.957  val(tf) 0.1411/0.978  KL 0.02
# Epoch 57: train 0.3737/0.958  val(tf) 0.1396/0.978  KL 0.02
# Epoch 58: train 0.3705/0.959  val(tf) 0.1355/0.980  KL 0.02
# Epoch 59: train 0.3673/0.960  val(tf) 0.1354/0.979  KL 0.02
# Epoch 60: train 0.3643/0.961  val(tf) 0.1309/0.981  beam_acc 0.903  valid 0.907  lev 2.80  KL 0.02
# Epoch 61: train 0.3612/0.962  val(tf) 0.1292/0.982  KL 0.02
# Epoch 62: train 0.3581/0.963  val(tf) 0.1306/0.981  KL 0.02
# Epoch 63: train 0.3551/0.964  val(tf) 0.1264/0.982  KL 0.02
# Epoch 64: train 0.3525/0.965  val(tf) 0.1226/0.983  KL 0.02
# Epoch 65: train 0.3501/0.966  val(tf) 0.1232/0.983  beam_acc 0.910  valid 0.906  lev 2.58  KL 0.02
# Epoch 66: train 0.3471/0.967  val(tf) 0.1196/0.984  KL 0.02
# Epoch 67: train 0.3449/0.967  val(tf) 0.1190/0.984  KL 0.02
# Epoch 68: train 0.3429/0.968  val(tf) 0.1184/0.984  KL 0.02
# Epoch 69: train 0.3402/0.969  val(tf) 0.1173/0.984  KL 0.02
# Epoch 70: train 0.3381/0.969  val(tf) 0.1172/0.984  beam_acc 0.915  valid 0.915  lev 2.39  KL 0.02
# Epoch 71: train 0.3359/0.970  val(tf) 0.1126/0.986  KL 0.02
# Epoch 72: train 0.3338/0.971  val(tf) 0.1135/0.985  KL 0.02
# Epoch 73: train 0.3320/0.971  val(tf) 0.1091/0.987  KL 0.02
# Epoch 74: train 0.3300/0.972  val(tf) 0.1099/0.987  KL 0.02
# Epoch 75: train 0.3283/0.972  val(tf) 0.1083/0.987  beam_acc 0.931  valid 0.933  lev 1.94  KL 0.02
# Epoch 76: train 0.3263/0.973  val(tf) 0.1070/0.987  KL 0.02
# Epoch 77: train 0.3244/0.973  val(tf) 0.1044/0.988  KL 0.02
# Epoch 78: train 0.3228/0.974  val(tf) 0.1038/0.988  KL 0.02
# Epoch 79: train 0.3212/0.974  val(tf) 0.1024/0.989  KL 0.02
# Epoch 80: train 0.3194/0.975  val(tf) 0.1011/0.989  beam_acc 0.941  valid 0.943  lev 1.69  KL 0.02
# Epoch 81: train 0.3176/0.975  val(tf) 0.1007/0.989  KL 0.02
# Epoch 82: train 0.3163/0.976  val(tf) 0.0998/0.989  KL 0.02
# Epoch 83: train 0.3148/0.976  val(tf) 0.0987/0.989  KL 0.02
# Epoch 84: train 0.3134/0.976  val(tf) 0.0979/0.990  KL 0.02
# Epoch 85: train 0.3119/0.977  val(tf) 0.0967/0.990  beam_acc 0.949  valid 0.949  lev 1.46  KL 0.02
# Epoch 86: train 0.3105/0.977  val(tf) 0.0953/0.990  KL 0.02
# Epoch 87: train 0.3090/0.978  val(tf) 0.0937/0.991  KL 0.02
# Epoch 88: train 0.3078/0.978  val(tf) 0.0941/0.991  KL 0.02
# Epoch 89: train 0.3064/0.978  val(tf) 0.0942/0.990  KL 0.02
# Epoch 90: train 0.3051/0.979  val(tf) 0.0922/0.991  beam_acc 0.956  valid 0.959  lev 1.26  KL 0.02
# Epoch 91: train 0.3038/0.979  val(tf) 0.0929/0.991  KL 0.02
# Epoch 92: train 0.3027/0.979  val(tf) 0.0913/0.991  KL 0.02
# Epoch 93: train 0.3013/0.980  val(tf) 0.0898/0.992  KL 0.02
# Epoch 94: train 0.3000/0.980  val(tf) 0.0907/0.991  KL 0.02
# Epoch 95: train 0.2991/0.980  val(tf) 0.0911/0.991  beam_acc 0.959  valid 0.962  lev 1.15  KL 0.02
# Epoch 96: train 0.2979/0.981  val(tf) 0.0882/0.992  KL 0.02
# Epoch 97: train 0.2970/0.981  val(tf) 0.0865/0.992  KL 0.02
# Epoch 98: train 0.2959/0.981  val(tf) 0.0879/0.992  KL 0.02
# Epoch 99: train 0.2947/0.981  val(tf) 0.0884/0.992  KL 0.02
# Epoch 100: train 0.2937/0.982  val(tf) 0.0848/0.993  beam_acc 0.966  valid 0.969  lev 0.97  KL 0.02
# Total training time: 135.59 min

# %%
plt.plot_training_curves(history, metrics_every=cfg["metrics_every"], save_path=os.path.join(cfg["save_dir"], "training_curves.png"))
# Out:
# [plot] saved to ./checkpoints/training_curves.png
# (<Figure size 1500x800 with 6 Axes>,
#  array([[<Axes: title={'center': 'Loss'}, ylabel='CE+KL'>,
#          <Axes: title={'center': 'Token level Acc'}>,
#          <Axes: title={'center': 'Validation accuracy with beam search'}>],
#         [<Axes: title={'center': 'Validity Ratio'}, xlabel='epoch'>,
#          <Axes: title={'center': 'Average Levenshtein Distance'}, xlabel='epoch'>,
#          <Axes: xlabel='epoch'>]], dtype=object))

# %%
# # ─── Cell 5 : SMILES reconstruction demo ─────────────────────────────────────

Dye_smiles = [
'CC1=CC(=O)c2c(Br)cc(Br)c(S(=O)(=O)O)c2C1=O',
'Cc1c(Br)cc(Br)c(C(C)c2ccc(C(C)C)c(Br)c2O)c1S(=O)(=O)O',
'Cc1ccccc1N=Nc1ccc(C(N)=O)cc1',
'Cc1ccc(-c2cccc(O)c2C(C)c2ccc(S(=O)(=O)O)cc2)cc1',
'CN(C)c1ccc2c(c1)CN=C2c1ccccc1',
'O=C1c2ccccc2C(=O)c2c(O)cccc21',
'O=C1Nc2ccccc2S(=O)(=O)[N-]c2c1cccc2S(=O)(=O)[O-]',
'CN(C)C1=CS(=O)(=O)c2ccc(N(C)C)cc21',
'CN(C)c1ccc(C(C)(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc2)cc1',
'Cc1ccc(C(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccc(C(C)C)cc2)cc1',
'CN(C)c1ccc2c(c1)CC1=CC(=[N+](C)C)C(=N2)C=C1',
'O=C1c2cc(=O)cccc2C(=O)c2c(Br)cc(Br)cc21',
'O=c1cc(O)ccc(-c2ccc3c(oc(=O)c4ccccc43)c2O)c1']


# Dye_names = [
#     'Bromophenol Blue',
#     'Bromothymol Blue',
#     'Acetic acid',
#     'Phenol Red',
#     'Neutral Red',
#     'Alizarin Red S',
#     'Indigo Carmine',
#     'Methylene Blue',
#     'Crystal Violet',
#     'Thymolphthalein',
#     'Safranin O',
#     'Eosin Y',
#     'Fluorescein']

# %%
m = model.module if isinstance(model, nn.DataParallel) else model
device = next(m.parameters()).device

df_rec = reconstruct_smiles_table(
    smiles_list=None,
    test_csv=cfg["test_files"][0],
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device,
    mode="beam",
    beam_size=cfg["beam_size"])

df_rec.tail(20)
# Out:
#                                                  input  \
# 249        COC(=O)Cn1c(CCNC(=O)c2ccccc2)[nH+]c2ccccc21
# 250       CC(C)=CC(=O)NCc1cc[nH+]c(N2CCO[C@@H](C)C2)c1
# 251              [NH3+]CC1([C@H](O)c2ccccc2OC(F)F)CCC1
# 252  COC(=O)c1nn(CC(=O)NCCc2ccc(OC)c(OC)c2)c(=O)c2n...
# 253  Cc1cnc(NC(=O)N[C@@H](C)c2ccc(S(=O)(=O)N(C)C)cc...
# 254  CCOC(=O)c1cnn([C@H]2CCCN(C(=O)Nc3cccc(N(C)CC)c...
# 255  CCCCNC(=O)[C@H]1[C@H]2C=C[C@]3(CN(c4cc(C)on4)C...
# 256  CC(C)[C@@H]1CN(Cc2c[nH]nc2-c2ccc(Cl)cc2)C[C@H]...
# 257                 CC(C)N(Cc1ccc(Cl)nc1)C[C@H]1CCCCO1
# 258           c1ccc(-c2nc(CN3CCC[C@H]3c3ccccc3)no2)cc1
# 259                 CC(C)C[C@@H](CN)C(=O)NCCCC(=O)[O-]
# 260    O[C@H](C[C@H]1CCCN1c1ccc(OC(F)F)cn1)c1ccc(F)cc1
# 261  CCn1nc(C(=O)[O-])c2c1CC[C@@H]([NH2+]CCCN1CCOCC...
# 262           Cc1nn(CCO)c(C)c1C[NH+]1CCC[C@@](C)(CO)C1
# 263  O=C1C[C@@H](CNC(=O)Nc2cccc(-c3ncon3)c2)c2ccccc2N1
# 264       O=S(=O)([O-])C1=CC2=NC(c3ccccc3)=N[C@H]2C=C1
# 265                CN(Cc1nccs1)C(=O)[C@@H]1CSc2ccccc21
# 266    CCCN(CC(F)F)C(=O)N[C@H](C)c1nc(-c2cccc(F)c2)no1
# 267            Cc1cc(NC(=O)c2ccc3[nH]c[nH+]c3c2)ncc1Br
# 268  Cc1ccc(O[C@H](C)C(=O)Nc2ccc(S(=O)(=O)[N-]c3cc(...
#
#                                          reconstructed valid  lev
# 249        COC(=O)Cn1c(CCNC(=O)c2ccccc2)[nH+]c2ccccc21   yes    0
# 250       CC(C)=CC(=O)NCc1cc[nH+]c(N2CCO[C@@H](C)C2)c1   yes    0
# 251              [NH3+]CC1([C@H](O)c2ccccc2OC(F)F)CCC1   yes    0
# 252  COC(=O)c1nn(CC(=O)NCCc2ccc(OC)c(OC)c2)c(=O)c2n...   yes    0
# 253  Cc1cnc(NC(=O)N[C@@H](C)c2ccc(S(=O)(=O)N(C)C)cc...   yes    0
# 254  CCOC(=O)c1cnn([C@H]2CCCN(C(=O)Nc3cccc(N(C)CC)c...   yes    0
# 255  CCCCNC(=O)[C@H]1[C@H]2C=C[C@]3(CN(c4cc(C)on4)C...   yes    2
# 256  CC(C)[C@@H]1CN(Cc2c[nH]nc2-c2ccc(Cl)cc2)C[C@H]...   yes    0
# 257                 CC(C)N(Cc1ccc(Cl)nc1)C[C@H]1CCCCO1   yes    0
# 258           c1ccc(-c2nc(CN3CCC[C@H]3c3ccccc3)no2)cc1   yes    0
# 259                 CC(C)C[C@@H](CN)NC(=O)CCCC(=O)[O-]   yes    2
# 260    O[C@H](C[C@H]1CCCN1c1ccc(OC(F)F)cn1)c1ccc(F)cc1   yes    0
# 261  CCn1nc(C(=O)[O-])c2c1CC[C@@H]([NH2+]CCCN1CCOCC...   yes    0
# 262           Cc1nn(CCO)c(C)c1C[NH+]1CCC[C@@](C)(CO)C1   yes    0
# 263  O=C1C[C@@H](CNC(=O)Nc2cccc(-c3ncon3)c2)c2ccccc2N1   yes    0
# 264       O=S(=O)([O-])C1=CC2=NC(c3ccccc3)=N[C@H]2C=C1   yes    0
# 265                CN(Cc1nccs1)C(=O)[C@@H]1CSc2ccccc21   yes    0
# 266    CCCN(CC(F)F)C(=O)N[C@H](C)c1nc(-c2cccc(F)c2)no1   yes    0
# 267            Cc1cc(NC(=O)c2ccc3[nH]c[nH+]c3c2)ncc1Br   yes    0
# 268  Cc1ccc(O[C@H](C)C(=O)Nc2ccc(S(=O)(=O)[N-]c3cc(...   yes    0

# %%
# ------------------------------------------------------------------
# 1.  Token-level accuracy (micro-average over SMILES tokens)
# ------------------------------------------------------------------
def token_accuracy_row(gold, pred):
    g = du.tokenize_smiles(gold)
    p = du.tokenize_smiles(pred)
    L = min(len(g), len(p))
    if L == 0:                      # degenerate empty case
        return 0, 0
    correct = sum(gi == pi for gi, pi in zip(g[:L], p[:L]))
    total   = L
    return correct, total

tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy (beam): {exact_match_acc:.4f}")
# Out:
# Token level test accuracy (beam): 0.9563
# Exact SMILES match accuracy (beam): 0.8550

# %%
df_rec = reconstruct_smiles_table(
    smiles_list=None,
    test_csv="/home/md_halim_mondol/Data/VOC_Dye.csv",
    model=m,
    token_to_idx=token_to_idx,
    idx_to_token=idx_to_token,
    seq_length=cfg["seq_length"],
    pad_idx=cfg["pad_idx"],
    sos_idx=cfg["sos_idx"],
    eos_idx=cfg["eos_idx"],
    device=device,
    mode="beam",
    beam_size=cfg["beam_size"])

df_rec.tail(50)
# Out:
#       input                   reconstructed valid  lev
# 910   O=S=O          OOSc1ccc(C(=O)[O-])cc1   yes   18
# 911   O=S=O         OOc1ccc(C(=O)[O-])cc1Br   yes   20
# 912   O=S=O        OOSc1ccc(C(=O)[O-])cc1Br   yes   20
# 913   O=S=O          OOSc1ccc(C(=O)[O-])cc1   yes   18
# 914   O=S=O      O=[N-]Sc1ccc(C(=O)[O-])cc1    no   21
# 915   O=S=O         OOc1ccc(C(=O)[O-])cc1Br   yes   20
# 916   O=S=O        OOSc1ccc(C(=O)[O-])cc1Br   yes   20
# 917   O=S=O        OOSc1ccc(C(=O)[O-])cc1Br   yes   20
# 918   O=S=O         OOc1ccc(C(=O)[O-])cc1Br   yes   20
# 919   O=S=O        OOSc1ccc(C(=O)[O-])cc1Br   yes   20
# 920   O=S=O           OOc1cc(F)cn1-c1ccccc1   yes   20
# 921   O=S=O          OOSc1ccc(C(=O)[O-])cc1   yes   18
# 922   O=S=O         O=OSc1ccc(C(=O)[O-])cc1    no   18
# 923   O=S=O         OOc1cc(F)cc(=O)[nH]c1=O   yes   19
# 924  CN(C)C      CN(C)Cc1cc[nH+]c(C(=O)N)n1   yes   20
# 925  CN(C)C      CN(C)Cc1cc(CN)c[nH+]c1[O-]   yes   20
# 926  CN(C)C     CN[C@H](C)c1ccc([C@H]1C)cc1    no   21
# 927  CN(C)C             CN(C)COc1cnc2c1OCC2    no   13
# 928  CN(C)C       CN[C@H](C)c1ccc(C(=O)N)n1    no   19
# 929  CN(C)C                          N(C)CC   yes    2
# 930  CN(C)C                          N(C)CC   yes    2
# 931  CN(C)C            CN(C)COc1cnc(Br)cc1C   yes   14
# 932  CN(C)C           CN(C)Cc1cc2nc(OC)cn12   yes   15
# 933  CN(C)C                    CN(C)C(=O)OC   yes    6
# 934  CN(C)C                  CN(C)C(=O)[O-]   yes    8
# 935  CN(C)C          CN(C)Cc1cc[nH+]c(OC)n1   yes   16
# 936  CN(C)C             CN(C)CO)Cc1[nH]ncc1    no   13
# 937  CN(C)C               CN(C)Cc1cc2n1OCC2    no   11
# 938  CN(C)C     CN[C@H](C)c1ccn(CO)c1[NH+]C   yes   21
# 939  CN(C)C                               N   yes    5
# 940  CN(C)C           CN[C@H](C)c1ccn(C2CC1    no   15
# 941  CN(C)C                         NC(C)CO   yes    3
# 942  CN(C)C      CN[C@H](C)c1cc(C(=O)N)ncc1   yes   20
# 943  CN(C)C                           N(C)C   yes    1
# 944  CN(C)C  CN[C@H](C)c1ccc(C(=O)N)c[nH+]1   yes   24
# 945  CN(C)C       CN(C)Cc1cc(C(=O)N)[nH+]c1    no   19
# 946  CN(C)C           CN[C@H](C)c1ccn(C2CC1    no   15
# 947  CN(C)C                     CN[C@H](C)C   yes    5
# 948  CN(C)C                  CN(C)COc1cnco1   yes    8
# 949  CN(C)C       CN[C@H](C)c1ccc(C(=O)N)s1   yes   19
# 950  CN(C)C             CN(C)C)Cc1c(NC)scc1    no   13
# 951  CN(C)C        CN[C@H](C)c1ccc(C2CN2)s1   yes   18
# 952  CN(C)C                     nN1OCCC1(C)    no    8
# 953  CN(C)C        NC[C@H](C)c1ccc(C2NC2)s1   yes   19
# 954  CN(C)C                          CN(C)C   yes    0
# 955  CN(C)C       CN[C@H](C)c1cc(C(=O)N)sc1   yes   19
# 956  CN(C)C               CN(C)Cc1cc(CN)co1   yes   11
# 957  CN(C)C                        CN(C)COC   yes    2
# 958  CN(C)C       [C@H](C)NCc1cc(C#N)c[nH]1   yes   20
# 959  CN(C)C       CN[C@H](C)c1ccc(C(=O)N)s1   yes   19

# %%
tot_corr = tot_tok = 0
for g, p in zip(df_rec["input"], df_rec["reconstructed"]):
    c, t = token_accuracy_row(g, p)
    tot_corr += c
    tot_tok  += t

beam_token_acc = tot_corr / tot_tok if tot_tok else 0.0
print(f"Token level test accuracy for Dye SMILES (beam): {beam_token_acc:.4f}")

# ------------------------------------------------------------------
# 2.  Sequence-level (exact-match) accuracy
# ------------------------------------------------------------------
exact_match_acc = (df_rec["input"] == df_rec["reconstructed"]).mean()
print(f"Exact SMILES match accuracy for Dye SMILES (beam): {exact_match_acc:.4f}")
# Out:
# Token level test accuracy for Dye SMILES (beam): 0.4173
# Exact SMILES match accuracy for Dye SMILES (beam): 0.0719
